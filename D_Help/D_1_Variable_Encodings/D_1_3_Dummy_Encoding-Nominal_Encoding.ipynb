# %% [markdown]
# ### Dummy Encoding - Nominal Encoding

# %% [markdown]
# ![Dummy%20Encoder.jpg](attachment:Dummy%20Encoder.jpg)

# %%
import pandas as pd

# %%
df0 = pd.read_csv("../../C_Datasets/titanic_train_original.csv")
df  = df0[['Sex', 'Embarked', 'Survived']]
df.head()
# Out:
#       Sex Embarked  Survived
# 0    male        S         0
# 1  female        C         1
# 2  female        S         1
# 3  female        S         1
# 4    male        S         0

# %% [markdown]
# ### 1) Default get_dummies()

# %%
pd.get_dummies(df, columns=['Embarked'])
# Out:
#         Sex  Survived  Embarked_C  Embarked_Q  Embarked_S
# 0      male         0       False       False        True
# 1    female         1        True       False       False
# 2    female         1       False       False        True
# 3    female         1       False       False        True
# 4      male         0       False       False        True
# ..      ...       ...         ...         ...         ...
# 886    male         0       False       False        True
# 887  female         1       False       False        True
# 888  female         0       False       False        True
# 889    male         1        True       False       False
# 890    male         0       False        True       False
#
# [891 rows x 5 columns]

# %% [markdown]
# ### 2) get_dummies() with prefix parameter

# %%
pd.get_dummies(df, columns=['Embarked'], prefix='Emb', prefix_sep='-')
# Out:
#         Sex  Survived  Emb-C  Emb-Q  Emb-S
# 0      male         0  False  False   True
# 1    female         1   True  False  False
# 2    female         1  False  False   True
# 3    female         1  False  False   True
# 4      male         0  False  False   True
# ..      ...       ...    ...    ...    ...
# 886    male         0  False  False   True
# 887  female         1  False  False   True
# 888  female         0  False  False   True
# 889    male         1   True  False  False
# 890    male         0  False   True  False
#
# [891 rows x 5 columns]

# %%
pd.get_dummies(df, columns=['Embarked'], prefix='', prefix_sep='')
# Out:
#         Sex  Survived      C      Q      S
# 0      male         0  False  False   True
# 1    female         1   True  False  False
# 2    female         1  False  False   True
# 3    female         1  False  False   True
# 4      male         0  False  False   True
# ..      ...       ...    ...    ...    ...
# 886    male         0  False  False   True
# 887  female         1  False  False   True
# 888  female         0  False  False   True
# 889    male         1   True  False  False
# 890    male         0  False   True  False
#
# [891 rows x 5 columns]

# %% [markdown]
# ### 2) get_dummies() with drop_first parameter

# %%
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True, dtype='int')
df
# Out:
#         Sex  Survived  Embarked_Q  Embarked_S
# 0      male         0           0           1
# 1    female         1           0           0
# 2    female         1           0           1
# 3    female         1           0           1
# 4      male         0           0           1
# ..      ...       ...         ...         ...
# 886    male         0           0           1
# 887  female         1           0           1
# 888  female         0           0           1
# 889    male         1           0           0
# 890    male         0           1           0
#
# [891 rows x 4 columns]

# %%
df.columns = ['Sex', 'Survived', 'C', 'Q']

# %%
df.iloc[[291, 412, 255, 538, 17], :]
# Out:
#         Sex  Survived  C  Q
# 291  female         1  0  0
# 412  female         1  1  0
# 255  female         1  0  0
# 538    male         0  0  1
# 17     male         1  0  1
